# %% [markdown]
# # !!! Tidak usah menggunakan program ini. !!!

# %% [markdown]
# # Mempreproses file DATA C-DESA NOBOREJO.csv

# %% [markdown]
# ## 1. Menyiapkan coding environment, termasuk menginstall dan/atau memperbarui library

# %%
# Menginstall library-library
# !pip install pandas

# Mengimport library-library
import pandas as pd

# %% [markdown]
# ## 2. Membaca file DATA C-DESA NOBOREJO.csv

# %%
# Membaca file DATA C-DESA NOBOREJO.csv
file_path = 'DATA C-DESA NOBOREJO.csv'
df = pd.read_csv(file_path)

# %%
# Menampilkan 5 data teratas
df.head()
# Out:
#                           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  KELURAHAN NOBOREJO            NaN        NaN        NaN        NaN
# 1                 NaN            NaN        NaN        NaN        NaN
# 2                  NO   NAMA PEMILIK     ALAMAT     C-DESA       LUAS
# 3                 NaN            NaN        NaN        NaN        NaN
# 4                   1  BENGKOK LURAH        NaN        1 A     11,380
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 13  \
# 0        NaN         NaN        NaN         NaN         NaN  ...          NaN
# 1        NaN         NaN        NaN         NaN         NaN  ...          NaN
# 2        KET         NaN        NaN         NaN         NaN  ...          NaN
# 3        NaN         NaN        NaN         NaN         NaN  ...          NaN
# 4        NaN         1.0      ?????         NaN         NaN  ...          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %% [markdown]
# ## 3. Preproses data untuk membuat membaca file .csv lebih lebih mudah

# %%
# Menghapus baris-baris kosong
df = df.dropna(how='all')

# Menghapus kolom-kolom kosong
df = df.dropna(axis=1, how='all')


# Menampilkan 5 data teratas
df.head()
# Out:
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  KELURAHAN NOBOREJO               NaN        NaN        NaN        NaN
# 2                  NO      NAMA PEMILIK     ALAMAT     C-DESA       LUAS
# 4                   1     BENGKOK LURAH        NaN        1 A     11,380
# 5                   2     BENGKOK CARIK        NaN        1 B      3,990
# 6                   3  BENGKOK KAMITUWO                   1 C      2,285
#
#   Unnamed: 5  Unnamed: 6             Unnamed: 7
# 0        NaN         NaN                    NaN
# 2        KET         NaN                    NaN
# 4        NaN         1.0                  ?????
# 5        NaN         2.0  Fuad Anan 7 Juni 1995
# 6        NaN         3.0             Kas Desa,

# %%
# Menghapus baris pertama yang berisi "KELURAHAN NOBOREJO"
df = df[df.apply(lambda row: row.astype(str).str.contains('KELURAHAN NOBOREJO').any(), axis=1) == False]

# %%
# Membuat header
df.columns = ['NO', 'NAMA PEMILIK', 'ALAMAT', 'C-DESA', 'LUAS', 'KET', 'REDUNDANT', 'DESKRIPSI']

# Mentampilkan 5 data teratas
df.head()
# Out:
#    NO      NAMA PEMILIK  ALAMAT  C-DESA    LUAS  KET  REDUNDANT  \
# 2  NO      NAMA PEMILIK  ALAMAT  C-DESA    LUAS  KET        NaN
# 4   1     BENGKOK LURAH     NaN     1 A  11,380  NaN        1.0
# 5   2     BENGKOK CARIK     NaN     1 B   3,990  NaN        2.0
# 6   3  BENGKOK KAMITUWO             1 C   2,285  NaN        3.0
# 7   4     BENGKOK BEKEL     NaN     1 D   2,155  NaN        4.0
#
#                DESKRIPSI
# 2                    NaN
# 4                  ?????
# 5  Fuad Anan 7 Juni 1995
# 6             Kas Desa,
# 7                     ..

# %%
# Identifikasi dan menghitung baris-baris duplikat
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {len(duplicate_rows)}")
print(duplicate_rows)
# Out:
# Number of duplicate rows: 2
#       NO NAMA PEMILIK ALAMAT C-DESA LUAS  KET  REDUNDANT DESKRIPSI
# 729  NaN          NaN    NaN    NaN  NaN  NaN        NaN    4499.2
# 731  NaN          NaN    NaN    NaN  NaN  NaN        NaN    8509.5

# %%
# Menghapus baris-baris duplikat
df = df.drop_duplicates()

# Mentampilkan 5 data teratas
df.head()
# Out:
#    NO      NAMA PEMILIK  ALAMAT  C-DESA    LUAS  KET  REDUNDANT  \
# 2  NO      NAMA PEMILIK  ALAMAT  C-DESA    LUAS  KET        NaN
# 4   1     BENGKOK LURAH     NaN     1 A  11,380  NaN        1.0
# 5   2     BENGKOK CARIK     NaN     1 B   3,990  NaN        2.0
# 6   3  BENGKOK KAMITUWO             1 C   2,285  NaN        3.0
# 7   4     BENGKOK BEKEL     NaN     1 D   2,155  NaN        4.0
#
#                DESKRIPSI
# 2                    NaN
# 4                  ?????
# 5  Fuad Anan 7 Juni 1995
# 6             Kas Desa,
# 7                     ..

# %%
# Menghapus baris pertama
df = df.iloc[1:]

# Mentampilkan 5 data teratas
df.head()
# Out:
#   NO      NAMA PEMILIK ALAMAT C-DESA    LUAS  KET  REDUNDANT  \
# 4  1     BENGKOK LURAH    NaN    1 A  11,380  NaN        1.0
# 5  2     BENGKOK CARIK    NaN    1 B   3,990  NaN        2.0
# 6  3  BENGKOK KAMITUWO           1 C   2,285  NaN        3.0
# 7  4     BENGKOK BEKEL    NaN    1 D   2,155  NaN        4.0
# 8  5     BENGKOK BEKEL    NaN    1 E   1,600  NaN        5.0
#
#                                          DESKRIPSI
# 4                                            ?????
# 5                            Fuad Anan 7 Juni 1995
# 6                                       Kas Desa,
# 7                                               ..
# 8  260 : ......, 630 : 7 Juni 1995, 710 : Sutamjiz

# %%
# Menghapus kolom 'REDUNDANT'
df = df.drop(columns=['REDUNDANT'])

# Mentampilkan 5 data teratas
df.head()
# Out:
#   NO      NAMA PEMILIK ALAMAT C-DESA    LUAS  KET  \
# 4  1     BENGKOK LURAH    NaN    1 A  11,380  NaN
# 5  2     BENGKOK CARIK    NaN    1 B   3,990  NaN
# 6  3  BENGKOK KAMITUWO           1 C   2,285  NaN
# 7  4     BENGKOK BEKEL    NaN    1 D   2,155  NaN
# 8  5     BENGKOK BEKEL    NaN    1 E   1,600  NaN
#
#                                          DESKRIPSI
# 4                                            ?????
# 5                            Fuad Anan 7 Juni 1995
# 6                                       Kas Desa,
# 7                                               ..
# 8  260 : ......, 630 : 7 Juni 1995, 710 : Sutamjiz

# %%
# Save ke file .csv
df.to_csv('DATA C-DESA NOBOREJO preprocessed.csv', index=False)
